# %%
#create engine

import sqlalchemy as db

import urllib
params = urllib.parse.quote_plus("DRIVER={SQL Server};SERVER=TWINBANJ\MSSQLSERVERDEV;DATABASE=adamdb")

engine = db.create_engine("mssql+pyodbc:///?odbc_connect=%s" % params)


import pandas as pd
df3 = pd.read_sql('SELECT [index], [First Name], [Gender], [Salary], [Team] FROM employees', engine)
df3
# Out:
#       index   First Name  Gender  Salary                  Team
# 0       426         Todd    Male  134408       Human Resources
# 1       427        Frank    Male   71853                 Sales
# 2       428  Christopher    Male   68028               Finance
# 3       429         Rose  Female  149903       Human Resources
# 4       430       Andrea  Female   79123          Distribution
# 5       431      Charles    Male  104014                 Legal
# 6       432      Jessica    None  121160       Client Services
# 7       433        Wanda  Female   65362                 Legal
# 8       434        Joyce  Female   50701                  None
# 9       435        Billy    Male  144709          Distribution
# 10      436      Kathryn  Female   53061               Finance
# 11      437       Denise  Female   36697                 Sales
# 12      438        Jason    Male   69244                  None
# 13      439     Nicholas    Male  101036       Human Resources
# ...

# %%
df5 = df3.drop_duplicates('index')

df5.duplicated('First Name')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28       True
# 29      False
#         ...
# 1060     True
# 1061     True
# 1062     True
# 1064     True
# 1065     True
# 1066     True
# 1067     True
# 1068     True
# 1069     True
# 1070     True
# 1071     True
# 1073     True
# 1074     True
# 1075     True
# 1076     True
# 1077     True
# 1079     True
# 1080     True
# 1081     True
# 1082     True
# 1083     True
# 1084     True
# 1085     True
# 1086     True
# 1087     True
# 1088     True
# 1090     True
# 1091     True
# 1092     True
# 1093     True
# ...
